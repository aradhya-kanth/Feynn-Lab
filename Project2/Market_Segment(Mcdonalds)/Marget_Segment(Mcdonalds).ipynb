# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('https://homepage.boku.ac.at/leisch/MSA/datasets/mcdonalds.csv', sep = ',')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data
# Out:
#      yummy convenient spicy fattening greasy fast cheap tasty expensive  \
# 0       No        Yes    No       Yes     No  Yes   Yes    No       Yes
# 1      Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes
# 2       No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes
# 3      Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No
# 4       No        Yes    No       Yes    Yes  Yes   Yes    No        No
# 5      Yes        Yes    No       Yes     No  Yes   Yes   Yes        No
# 6      Yes        Yes   Yes       Yes     No  Yes    No   Yes       Yes
# 7      Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No
# 8       No         No    No       Yes    Yes   No    No    No       Yes
# 9      Yes        Yes    No       Yes    Yes  Yes    No   Yes       Yes
# 10      No        Yes    No       Yes     No  Yes   Yes    No        No
# 11     Yes        Yes    No       Yes    Yes  Yes    No   Yes       Yes
# ...

# %%
data.shape
# Out:
# (1453, 15)

# %%
data.columns
# Out:
# Index(['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap',
#        'tasty', 'expensive', 'healthy', 'disgusting', 'Like', 'Age',
#        'VisitFrequency', 'Gender'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %% [markdown]
# All columns are object type except
# 'Age' which is integer type

# %%
data.isnull().sum()
# Out:
# yummy             0
# convenient        0
# spicy             0
# fattening         0
# greasy            0
# fast              0
# cheap             0
# tasty             0
# expensive         0
# healthy           0
# disgusting        0
# Like              0
# Age               0
# VisitFrequency    0
# Gender            0
# dtype: int64

# %% [markdown]
# No null value...

# %%
data.describe()
# Out:
#                Age
# count  1453.000000
# mean     44.604955
# std      14.221178
# min      18.000000
# 25%      33.000000
# 50%      45.000000
# 75%      57.000000
# max      71.000000

# %%
data['Like'].value_counts()
# Out:
# +3              229
# +2              187
# 0               169
# +4              160
# +1              152
# I hate it!-5    152
# I love it!+5    143
# -3               73
# -4               71
# -2               59
# -1               58
# Name: Like, dtype: int64

# %% [markdown]
# Observation: we can do some preprocessing from this information.
# Like we can add new new column to the dataset with categoric specific e.g 'Like_+1', 'Like_+2'... and assign 1 to the value where those specific value would be there. And for its negative value assign -1 otherwise 0

# %%
data["Age"].value_counts()
# Out:
# 55    53
# 60    38
# 37    37
# 59    36
# 57    36
# 52    36
# 58    35
# 36    35
# 49    34
# 62    34
# 50    34
# 32    33
# 44    32
# 56    32
# 64    32
# 53    31
# 26    31
# 24    30
# 35    30
# 51    30
# 47    30
# 42    30
# 23    30
# 39    29
# 29    28
# 34    28
# 30    28
# 38    27
# 40    27
# 31    27
# 25    26
# 33    26
# 61    26
# 67    26
# 48    26
# 43    25
# 27    25
# 63    25
# 54    24
# 41    23
# 22    23
# 65    23
# 45    22
# 20    21
# 46    19
# 28    18
# 66    17
# 21    16
# 18    16
# 70    15
# 69    14
# 68    13
# 19    10
# 71     1
# Name: Age, dtype: int64

# %% [markdown]
# I would like to drop this column.

# %%
data['VisitFrequency'].nunique()
# Out:
# 6

# %%
data["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# ###### seggregate Continuous and categorical feature

# %%
cat =[]
cont =[]
for i in data.columns:
    if data[i].dtypes == 'object':
        cat.append(i)
    else:
        cont.append(i)

# %%
cat
# Out:
# ['yummy',
#  'convenient',
#  'spicy',
#  'fattening',
#  'greasy',
#  'fast',
#  'cheap',
#  'tasty',
#  'expensive',
#  'healthy',
#  'disgusting',
#  'Like',
#  'VisitFrequency',
#  'Gender']

# %%
cont
# Out:
# ['Age']

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(10, 40))
for i in enumerate(cat):
    plt.subplot(len(cat)//2, 2, i[0]+1)
    sns.countplot(data = data, x = i[1])
    plt.xticks(rotation = 45)

# %%
for i in enumerate(cont):
    plt.subplot(1, 2, i[0]+1)
    sns.distplot(data[i[1]])
# Out:
# C:\Users\aradh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Data Preprocessing

# %%
data_new = data.drop(labels=['Like','Age','VisitFrequency','Gender'], axis=1)

# %%
data_new.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting
# 0         No
# 1         No
# 2         No
# 3        Yes
# 4         No

# %%
from sklearn.preprocessing import LabelEncoder
data_encoded = data_new.apply(LabelEncoder().fit_transform)
data_encoded.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting
# 0        0           0
# 1        0           0
# 2        1           0
# 3        0           1
# 4        1           0

# %% [markdown]
# # Model

# %%
# !pip install -U yellowbrick
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\aradh\\anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Oblique.ttf'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aradh\anaconda3\lib\site-packages)
# ...
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# ...

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12)).fit(data_encoded)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from collections import Counter
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=0).fit(data_encoded)
data['cluster_num'] = kmeans.labels_ 
print ('Labels:', kmeans.labels_)
print ('WCSS:', kmeans.inertia_)
print('No. of iterations: ', kmeans.n_iter_)
print('Cluster centroids: ', kmeans.cluster_centers_)
print('Cluster size: ', Counter(kmeans.labels_))
# Out:
# Labels: [2 0 0 ... 0 1 3]
# WCSS: 1603.0604440558945
# No. of iterations:  7
# Cluster centroids:  [[0.85448916 0.9628483  0.13312693 0.90712074 0.61919505 0.86068111
#   0.10835913 0.93188854 0.89783282 0.20433437 0.10526316]
#  [0.88793103 0.98103448 0.0862069  0.79482759 0.32931034 0.96034483
#   0.92241379 0.97586207 0.01724138 0.32068966 0.04310345]
#  [0.02302632 0.89144737 0.07236842 0.92434211 0.66776316 0.96381579
#   0.93421053 0.15460526 0.01315789 0.07236842 0.38815789]
#  [0.0203252  0.68292683 0.08536585 0.91463415 0.69512195 0.73170732
#   0.06504065 0.08943089 0.87804878 0.06097561 0.71544715]]
# Cluster size:  Counter({1: 580, 0: 323, 2: 304, 3: 246})

# %%
data['VisitFrequency'] = LabelEncoder().fit_transform(data['VisitFrequency'])
visit = data.groupby('cluster_num')['VisitFrequency'].mean()
visit = visit.to_frame().reset_index()
visit
# Out:
#    cluster_num  VisitFrequency
# 0            0        2.547988
# 1            1        2.584483
# 2            2        2.822368
# 3            3        2.654472

# %%
# calculating the mean of 'Like'
data['Like'] = LabelEncoder().fit_transform(data['Like'])
Like = data.groupby('cluster_num')['Like'].mean()
Like = Like.to_frame().reset_index()
Like
# Out:
#    cluster_num      Like
# 0            0  3.798762
# 1            1  3.794828
# 2            2  5.430921
# 3            3  6.739837

# %%
data['Gender'] = LabelEncoder().fit_transform(data['Gender'])
Gender = data.groupby('cluster_num')['Gender'].mean()
Gender = Gender.to_frame().reset_index()
Gender
# Out:
#    cluster_num    Gender
# 0            0  0.523220
# 1            1  0.398276
# 2            2  0.411184
# 3            3  0.569106

# %%
segment = Gender.merge(Like, on='cluster_num', how='left').merge(visit, on='cluster_num', how='left')
segment
# Out:
#    cluster_num    Gender      Like  VisitFrequency
# 0            0  0.523220  3.798762        2.547988
# 1            1  0.398276  3.794828        2.584483
# 2            2  0.411184  5.430921        2.822368
# 3            3  0.569106  6.739837        2.654472

# %%
plt.figure(figsize = (9,4))
sns.scatterplot(x = "VisitFrequency", y = "Like",data=segment,s=400, color="r")
plt.title("Simple segment evaluation plot for the fast food data set", fontsize = 15) 
plt.xlabel("Visit", fontsize = 12) 
plt.ylabel("Like", fontsize = 12) 
plt.show()
